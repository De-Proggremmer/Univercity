# %% [markdown]
# <a href="https://colab.research.google.com/github/De-Proggremmer/Univercity/blob/main/Tasks/%D0%94%D0%BE%D0%BF%D0%BE%D0%BB%D0%BD%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%BE%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%E2%84%963_%D0%9E%D0%B1%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0_%D0%B8%D1%81%D0%BA%D0%BB%D1%8E%D1%87%D0%B5%D0%BD%D0%B8%D0%B9_%D0%B8_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%D1%81_%D1%82%D0%B5%D0%BA%D1%81%D1%82%D0%BE%D0%B2%D1%8B%D0%BC%D0%B8_%D1%84%D0%B0%D0%B9%D0%BB%D0%B0%D0%BC%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Дополнительное задание №3. Обработка исключений и работа с текстовыми файлами**

# %% [markdown]
# **БАЗА:**
#
# - **Обработка исключений** позволяет перехватывать и обрабатывать ошибки, возникающие при выполнении программы, предотвращая её аварийное завершение.
# - **Работа с файлами** - важный навык для чтения, записи и обработки текстовой информации в Python.
#
# ---

# %% [markdown]
# ## **I. Обработка исключений**

# %% [markdown]
# ### **Пункт №1. Обработка некорректного индекса (IndexError)**

# %% [markdown]
# Создайте список из нескольких элементов (например, [10, 20, 30]). Попросите пользователя ввести индекс элемента, который нужно вывести. Если пользователь введёт индекс, выходящий за границы списка, перехватите IndexError и сообщите об этом.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте список из минимум 5 элементов
# - Покажите содержимое списка перед работой
# - Протестируйте минимум 4 случая (корректный индекс, отрицательный, слишком большой, нечисловое значение)

# %%
list1 = [0, 1, 2, 3, 4, 5]
print(list1)

def print_index(i):
  try:
    print("Index: ", i, "; Value: ", list1[i])
  except IndexError:
    print("wrong index")
  except TypeError:
    print("wrong index")

for i in range(4):
  index = input()
  if index.isdigit(): index = int(index)
  elif index[1:].isdigit(): index = - int(index[1:])
  print_index(index)
# Out:
# [0, 1, 2, 3, 4, 5]
# 1
# Index:  1 ; Value:  1
# -2
# Index:  -2 ; Value:  4
# 26
# wrong index
# d
# wrong index

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №2. Обработка исключений в цикле**

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя числа и добавляет их в список.
# - Если пользователь вводит некорректные данные, программа должна выводить сообщение об ошибке и продолжать работу.
# - Для выхода из программы пользователь должен ввести "стоп".
#
# **ОБЯЗАТЕЛЬНО:**
# - Покажите процесс ввода минимум 7 значений (включая ошибочные)
# - Выведите финальный список и статистику (сколько чисел введено успешно, сколько ошибок)

# %% [markdown]
# ```
# # Пример:
# # Введите число: 10
# # Введите число: текст (Ошибка: это не число)
# # Введите число: стоп
# # Итоговый список: [10]
# ```

# %%
l = []
cnt = 0

while True:
  n = input()
  if n == 'стоп': break
  try:
      n = int(n)
      l.append(n)
  except ValueError:
    cnt += 1
    print("Value is not correct!")

print(l, f"\n Кол-во чисел: {len(l)}, \nкол-во ошибок: {cnt}")
# Out:
# 1
# 4
# ав
# Value is not correct!
# йцукен
# Value is not correct!
# 43363
# -1343235
# стоп
# [1, 4, 43363, -1343235]
#  Кол-во чисел: 4,
# кол-во ошибок: 2

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №3**

# %% [markdown]
# Создайте функцию `get_list_element(lst, index)`, которая безопасно извлекает элемент списка по индексу с использованием блоков `try`, `except`, `else` и `finally`.
#
# Функция должна:
# - Обрабатывать выход за пределы списка
# - Обрабатывать некорректный тип индекса
# - Выводить сообщение о попытке доступа в блоке `finally`
#
# **ОБЯЗАТЕЛЬНО:**
# - Выведите результаты для минимум 4 различных случаев (успешный доступ, выход за границы, отрицательный индекс, нечисловой индекс)
# - Покажите, что блок `finally` выполняется всегда
#
# ```python
# # Пример использования:
# my_list = [1, 2, 3, 4, 5]
# get_list_element(my_list, 2)   # Вывод: "Элемент: 3", "Попытка доступа завершена"
# get_list_element(my_list, 10)  # Вывод: "Индекс вне диапазона", "Попытка доступа завершена"
# ```

# %%
def get_list_element(lst: list, index):
  try:
    el = lst.pop(index)
    print(f"Элемент с индексом {index}: {el}")
  except IndexError:
    print("Индекс за пределами доступа")
  except TypeError:
    print("Некорректый индекс")
  finally:
    print(f"Попытка обатиться к элементу по индексу: {index} \n")

my_list = [1, 2, 3, 4, 5]
get_list_element(my_list, 2)
get_list_element(my_list, 10)
get_list_element(my_list, -2)
get_list_element(my_list, "dfsdfsf")
# Out:
# Элемент с индексом 2: 3
# Попытка обатиться к элементу по индексу: 2
#
# Индекс за пределами доступа
# Попытка обатиться к элементу по индексу: 10
#
# Элемент с индексом -2: 4
# Попытка обатиться к элементу по индексу: -2
#
# Некорректый индекс
# Попытка обатиться к элементу по индексу: dfsdfsf

# %% [markdown]
# ---

# %% [markdown]
# ## **II. Работа с текстовыми файлами**

# %% [markdown]
# ### **Пункт №1. Запись в файл**

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя строку и записывает её в файл output.txt в режиме дозаписи.
#
# **ОБЯЗАТЕЛЬНО:**
# - Запросите у пользователя минимум 3 строки
# - Покажите содержимое файла после записи

# %%
with open("output.txt", "a") as f:
  for _ in range(20):
    f.write(f"{input()}\n")

print(open("output.txt").read())
# Out:
#                    -`
#                   .o+`
#                  `ooo/
#                 `+oooo:
#                `+oooooo:
#                -+oooooo+:
#              `/:-:++oooo+:
#             `/++++/+++++++:
#            `/++++++++++++++:
#           `/+++ooooooooooooo/`
#          ./ooosssso++osssssso+`
#         .oossssso-````/ossssss+`
#        -osssssso.      :ssssssso.
#       :osssssss/        osssso+++.
#      /ossssssss/        +ssssooo/-
#    `/ossssso+/:-        -:/+osssso+-
#   `+sso+:-`                 `.-/+oso:
#  `++:.                           `-/+/
#  .`                                 `

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №2. Чтение из файла**

# %% [markdown]
# Напишите программу, которая открывает файл output.txt и выводит его содержимое на экран.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте файл с минимум 5 строками текста
# - Покажите содержимое файла целиком
# - Обработайте случай отсутствующего файла

# %%
print(open("output.txt").read())

try:
  print(open("putput.txt").read())
except FileNotFoundError:
  print("Файл не существует")
# Out:
#                    -`
#                   .o+`
#                  `ooo/
#                 `+oooo:
#                `+oooooo:
#                -+oooooo+:
#              `/:-:++oooo+:
#             `/++++/+++++++:
#            `/++++++++++++++:
#           `/+++ooooooooooooo/`
#          ./ooosssso++osssssso+`
#         .oossssso-````/ossssss+`
#        -osssssso.      :ssssssso.
#       :osssssss/        osssso+++.
#      /ossssssss/        +ssssooo/-
#    `/ossssso+/:-        -:/+osssso+-
#   `+sso+:-`                 `.-/+oso:
#  `++:.                           `-/+/
#  .`                                 `
#
#
# Файл не существует

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №3. Подсчет строк в файле**

# %% [markdown]
# Напишите программу, которая открывает файл output.txt и подсчитывает количество строк в нём.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте тестовый файл с известным количеством строк (минимум 10)
# - Покажите первые 3 строки файла
# - Выведите общее количество строк
# - Выведите количество непустых строк

# %%
with open("output.txt") as f:
  l = f.readlines()
  for i in range(3): print(l[i], end='')
  print("\nКол-во строк: ", len(l))
  print("Кол-во непустых строк: ", len(l)-l.count("\n"))
# Out:
#                    -`
#                   .o+`
#                  `ooo/
#
# Кол-во строк:  20
# Кол-во непустых строк:  19

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №4. Копирование содержимого файла**

# %% [markdown]
# Напишите программу, которая копирует содержимое файла input.txt в файл output.txt.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте исходный файл с тестовым содержимым (минимум 5 строк)
# - Покажите содержимое исходного файла
# - Выполните копирование
# - Покажите содержимое скопированного файла
# - Обработайте случай отсутствия исходного файла

# %%
input_l = []
try:
  print(open("Input.txt").read())
  with open("Input.txt") as f:
    input_l = f.readlines()
    print(f.read())
except FileNotFoundError:
  print("Файл не существует!")

with open("Output.txt", "a") as f:
  for i in input_l:
    f.write(i)

print(open("Output.txt").read())
# Out:
# A
# B
# C
# D
# E
# F
#
# A
# B
# C
# D
# E
# F

# %% [markdown]
# ### **Пункт №5. Поиск слова в файле**

# %% [markdown]
# Напишите программу, которая открывает файл output.txt и проверяет, содержится ли в нём слово, введённое пользователем.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте файл с минимум 10 строками текста
# - Покажите содержимое файла
# - Протестируйте поиск минимум 5 различных слов
# - Выведите номера строк, где найдено слово
# - Покажите количество вхождений слова

# %%
def serch_in_file(word):

  with open("Output.txt") as f:
    l = list(map(lambda x: x[:-1], f.readlines()))
    print(f"Слово '{word}' находиться на сторках: ")
    for i in range(len(l)):
      if l[i] == word: print(i+1)
    print(f"Слов {word} в файле {l.count(word)} штук\n")

print(open("Output.txt").read(), "\n")

serch_in_file("альфа")
serch_in_file("зета")
serch_in_file("каппа")
serch_in_file("тета")
serch_in_file("ро")
serch_in_file("дельта")
# Out:
# альфа
# дельта
# бета
# гамма
# тета
# дельта
# фи
# пси
# кси
# пи
# эпсилон
# дельта
#
#
# Слово 'альфа' находиться на сторках:
# 1
# Слов альфа в файле 1 штук
#
# Слово 'зета' находиться на сторках:
# Слов зета в файле 0 штук
#
# Слово 'каппа' находиться на сторках:
# Слов каппа в файле 0 штук
#
# Слово 'тета' находиться на сторках:
# 5
# Слов тета в файле 1 штук
#
# Слово 'ро' находиться на сторках:
# Слов ро в файле 0 штук
#
# Слово 'дельта' находиться на сторках:
# 2
# 6
# 12
# Слов дельта в файле 3 штук

# %% [markdown]
# ### **Пункт №6. Чтение файла с обработкой FileNotFoundError**

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя имя файла и пытается открыть его. Если файла не существует, перехватите FileNotFoundError и выведите сообщение «Файл не найден!».
#
# **ОБЯЗАТЕЛЬНО:**
# - Протестируйте с существующим файлом
# - Протестируйте с несуществующим файлом
# - Покажите содержимое существующего файла

# %%
def open_file(filename):
  try:
    print(open(filename).read(), "\n")
  except FileNotFoundError:
    print("Файл не существует!")

open_file("Input.txt")
open_file("SomeFile.txt")
# Out:
# A
# B
# C
# D
# E
# F
#
# Файл не существует!

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №7. Подсчет статистики файла**

# %% [markdown]
# Напишите функцию `file_statistics(filename)`, которая читает текстовый файл и возвращает словарь со статистикой:
# - Количество строк
# - Количество слов
# - Количество символов (с пробелами и без)
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте тестовый файл с минимум 5 строками текста
# - Выведите содержимое файла ДО обработки
# - Выведите полученную статистику
# - Обработайте случай несуществующего файла
#
# ```python
# # Создание тестового файла
# test_content = """Первая строка текста
# Вторая строка с большим количеством слов
# Третья строка
# Четвертая строка для теста
# Пятая и последняя строка"""
#
# # Сохраните в файл и продемонстрируйте работу
# ```

# %%
def file_statistics(filename):
  d = {}
  with open(filename, "r") as f:
    l = f.readlines()
    d["Кол-во строк"] = len(l)
    l = ' '.join(l)
    d["Кол-во символов с проб"] = len(l)
    d["Кол-во символов без проб"] = len(l)-l.count(" ")
    l = l.split()
    d["Кол-во слов"] = len(l)

  for k in d.keys():
    print(k, d[k])

file = "Test.txt"
with open(file, "a") as f:
  f.write("Первая строка текста\n")
  f.write("Вторая строка с большим количеством слов\n")
  f.write("Третья строка\n")
  f.write("Четвертая строка для теста\n")
  f.write("Пятая и последняя строка\n")


file_statistics(file)
# Out:
# Кол-во строк 5
# Кол-во символов с проб 132
# Кол-во символов без проб 114
# Кол-во слов 19

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №8. Поиск и замена в файле**

# %% [markdown]
# Напишите функцию `replace_in_file(filename, old_text, new_text)`, которая заменяет все вхождения `old_text` на `new_text` в файле и сохраняет результат в новый файл с префиксом "modified_".
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте файл с текстом, содержащим минимум 3 вхождения заменяемого слова
# - Выведите содержимое файла ДО замены
# - Выполните замену
# - Выведите содержимое файла ПОСЛЕ замены
# - Покажите количество произведенных замен

# %%
from os import replace
def replace_in_file(filename, old_text, new_text):
  l = []
  cnt = 0
  with open(filename, "r") as f:
    l = f.read().split()
    for i in range(len(l)):
      if l[i] == old_text: l[i] = new_text; cnt += 1
  with open(f"modified_{filename}", "a") as f:
    for i in l: f.write(f"{i}\n")
  return cnt


def print_f(filename):
  print(filename, ":")
  with open(filename, "r") as f:
    for i in f.readlines(): print(i, end="")


filename = "test.txt"
with open(filename, "a") as f:
  f.write("альфа\n бета\n альфа\n гамма\n бета\n альфа\n гамма\n")

print_f(filename)
reps = replace_in_file(filename, "альфа", "эпсилон")
print_f(f"modified_{filename}")
print("Кол-во замен:", reps)
# Out:
# test.txt :
# альфа
#  бета
#  альфа
#  гамма
#  бета
#  альфа
#  гамма
# modified_test.txt :
# эпсилон
# бета
# эпсилон
# гамма
# бета
# эпсилон
# гамма
# Кол-во замен: 3

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №9. Объединение файлов**

# %% [markdown]
# Создайте функцию `merge_files(file_list, output_file)`, которая объединяет содержимое нескольких текстовых файлов в один, добавляя после каждого разделитель.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте минимум 3 файла с разным содержимым
# - Выведите содержимое КАЖДОГО исходного файла
# - Выполните объединение
# - Выведите содержимое результирующего файла

# %%
def print_f(filename):
  print(filename, ":")
  with open(filename, "r") as f:
    for i in f.readlines(): print(i, end="")
  print()


def merge_files(*files):
  l = []
  for file in files:
    with open(file, "r") as f:
      l.extend(f.read())
      l.append("\n----------\n")

  with open("merged.txt", "a") as f:
    for i in l: f.write(i)

file1, file2, file3 = "test1", "test2", "test3"
with open(file1, "a") as f: f.write("Т-90М Прорыв\n Т-80БВМ\n БМПТ Терминатор")
with open(file2, "a") as f: f.write("Су-25 Грач\n Су-34 Утенок\n Ту-160м2 Черный Лебедь")
with open(file3, "a") as f: f.write("КРГД Буревестник\n МБР Сармат\n ГАРК Кинжал\n")
print_f(file1); print_f(file2); print_f(file3)
merge_files(file1, file2, file3)
print_f("merged.txt")
# Out:
# test1 :
# Т-90М Прорыв
#  Т-80БВМ
#  БМПТ Терминатор
# test2 :
# Су-25 Грач
#  Су-34 Утенок
#  Ту-160м2 Черный Лебедь
# test3 :
# КРГД Буревестник
#  МБР Сармат
#  ГАРК Кинжал
#
# merged.txt :
# Т-90М Прорыв
#  Т-80БВМ
#  БМПТ Терминатор
# ----------
# Су-25 Грач
#  Су-34 Утенок
#  Ту-160м2 Черный Лебедь
# ----------
# КРГД Буревестник
#  МБР Сармат
#  ГАРК Кинжал
#
# ----------

# %% [markdown]
# ---
